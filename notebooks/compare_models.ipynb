# %%
import pandas as pd
import mlflow
from mlflow import MlflowClient

# %%
MLFLOW_TRACKING_URI='../models/mlruns'
MLFLOW_EXPERIMENT_NAME="skills_jobs_stackoverflow"

# %%
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
client=MlflowClient()

# %%
experiment=client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)
experiment
# Out:
# <Experiment: artifact_location=('file:///c:/Users/Mohamed '
#  'Mosaad/Downloads/first_git/data_science_project/notebooks/../models/mlruns/113844087145227590'), creation_time=1727992300252, experiment_id='113844087145227590', last_update_time=1727992300252, lifecycle_stage='active', name='skills_jobs_stackoverflow', tags={}>

# %%
runs=mlflow.search_runs([experiment.experiment_id])
runs
# Out:
#                              run_id       experiment_id    status  \
# 0  0f114561eea94a65b2b21f93b58af2d8  113844087145227590  FINISHED
# 1  ba946eb12bd24db6ba81b824d642bf90  113844087145227590  FINISHED
# 2  9476dd67930342fd8613e2af1e226bc0  113844087145227590  FINISHED
# 3  5252e0d0ca6a4ffa9e96fef11a250852  113844087145227590  FINISHED
# 4  a65d91e1791845a98dc4043e1d9df8fc  113844087145227590  FINISHED
#
#                                         artifact_uri  \
# 0  file:///c:/Users/Mohamed Mosaad/Downloads/firs...
# 1  file:///c:/Users/Mohamed Mosaad/Downloads/firs...
# 2  file:///c:/Users/Mohamed Mosaad/Downloads/firs...
# 3  file:///c:/Users/Mohamed Mosaad/Downloads/firs...
# 4  file:///c:/Users/Mohamed Mosaad/Downloads/firs...
#
#                         start_time                         end_time  \
# 0 2024-10-26 22:36:06.226000+00:00 2024-10-26 22:36:07.526000+00:00
# 1 2024-10-26 22:34:02.484000+00:00 2024-10-26 22:34:03.192000+00:00
# 2 2024-10-26 22:32:49.389000+00:00 2024-10-26 22:32:49.571000+00:00
# 3 2024-10-03 21:56:00.351000+00:00 2024-10-03 21:56:01.528000+00:00
# 4 2024-10-03 21:53:39.976000+00:00 2024-10-03 21:53:40.350000+00:00
#
#    metrics.recall_score  metrics.f1_score  metrics.accuracy_score  \
# 0              0.543410          0.682419                0.932541
# 1              0.537877          0.679435                0.931836
# 2              0.294902          0.380612                0.889095
# 3              0.546463          0.684104                0.932324
# 4              0.537877          0.679435                0.931836
#
#    metrics.precision_score tags.mlflow.source.type tags.mlflow.user  \
# 0                 0.939897                   LOCAL   Mohamed Mosaad
# 1                 0.945206                   LOCAL   Mohamed Mosaad
# 2                 0.620225                   LOCAL   Mohamed Mosaad
# 3                 0.937981                   LOCAL   Mohamed Mosaad
# 4                 0.945206                   LOCAL   Mohamed Mosaad
#
#                      tags.mlflow.runName  \
# 0  Random Forest: with PCA - Grid search
# 1        Random Forest: with PCA - Basic
# 2   Baseline model: Logistic Regression
# 3  Random Forest: with PCA - Grid search
# 4        Random Forest: with PCA - Basic
#
#                              tags.mlflow.source.name
# 0  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 1  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 2  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 3  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 4  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...

# %%
experiment = client.get_experiment_by_name(MLFLOW_EXPERIMENT_NAME)

# Check if experiment exists
if experiment is None:
    # If the experiment doesn't exist, handle it
    print(f"Experiment '{MLFLOW_EXPERIMENT_NAME}' not found!")
else:
    # Search for runs in the experiment
    runs = mlflow.search_runs([experiment.experiment_id])
    print(runs)
# Out:
#                              run_id       experiment_id    status  \
# 0  0f114561eea94a65b2b21f93b58af2d8  113844087145227590  FINISHED
# 1  ba946eb12bd24db6ba81b824d642bf90  113844087145227590  FINISHED
# 2  9476dd67930342fd8613e2af1e226bc0  113844087145227590  FINISHED
# 3  5252e0d0ca6a4ffa9e96fef11a250852  113844087145227590  FINISHED
# 4  a65d91e1791845a98dc4043e1d9df8fc  113844087145227590  FINISHED
#
#                                         artifact_uri  \
# 0  file:///c:/Users/Mohamed Mosaad/Downloads/firs...
# 1  file:///c:/Users/Mohamed Mosaad/Downloads/firs...
# 2  file:///c:/Users/Mohamed Mosaad/Downloads/firs...
# 3  file:///c:/Users/Mohamed Mosaad/Downloads/firs...
# 4  file:///c:/Users/Mohamed Mosaad/Downloads/firs...
#
#                         start_time                         end_time  \
# 0 2024-10-26 22:36:06.226000+00:00 2024-10-26 22:36:07.526000+00:00
# 1 2024-10-26 22:34:02.484000+00:00 2024-10-26 22:34:03.192000+00:00
# 2 2024-10-26 22:32:49.389000+00:00 2024-10-26 22:32:49.571000+00:00
# 3 2024-10-03 21:56:00.351000+00:00 2024-10-03 21:56:01.528000+00:00
# 4 2024-10-03 21:53:39.976000+00:00 2024-10-03 21:53:40.350000+00:00
#
#    metrics.recall_score  metrics.f1_score  metrics.accuracy_score  \
# 0              0.543410          0.682419                0.932541
# 1              0.537877          0.679435                0.931836
# 2              0.294902          0.380612                0.889095
# 3              0.546463          0.684104                0.932324
# 4              0.537877          0.679435                0.931836
#
#    metrics.precision_score tags.mlflow.source.type tags.mlflow.user  \
# 0                 0.939897                   LOCAL   Mohamed Mosaad
# 1                 0.945206                   LOCAL   Mohamed Mosaad
# 2                 0.620225                   LOCAL   Mohamed Mosaad
# 3                 0.937981                   LOCAL   Mohamed Mosaad
# 4                 0.945206                   LOCAL   Mohamed Mosaad
#
#                      tags.mlflow.runName  \
# 0  Random Forest: with PCA - Grid search
# 1        Random Forest: with PCA - Basic
# 2   Baseline model: Logistic Regression
# 3  Random Forest: with PCA - Grid search
# 4        Random Forest: with PCA - Basic
#
#                              tags.mlflow.source.name
# 0  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 1  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 2  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 3  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
# 4  c:\Users\Mohamed Mosaad\anaconda3\Lib\site-pac...
